# %%
import pandas as pd

# %%
df=pd.read_csv("F:\\placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df=df.iloc[:5,:3]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
s=df.axes #no of rows
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty #return true if data has missing values and if not then return false
b
# Out:
# False

# %%
i=df.ndim #no of axes(it is 2) {dimension}
i
# Out:
# 2

# %%
t=df.shape #shape=n(rows),n(columns)
t
# Out:
# (100, 3)

# %%
d=df.size #row count * column count
d
# Out:
# 300

# %%
a=df.values #return values of the dataset
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r=df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x=df.astype(int) #type conversion
x=df.astype(int) #
x
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
t=df.add(4)
t
# df['cgpa']=df['cgpa'].add(4)
# Out:
#      cgpa  resume_score  placed
# 0   16.14         10.52       5
# 1   14.17          9.17       4
# 2   16.27         12.86       5
# 3   14.88         11.27       5
# 4   15.52         11.30       5
# ..    ...           ...     ...
# 95  14.33         10.38       4
# 96  16.23         11.76       5
# 97  14.65         11.78       4
# 98  16.14          9.63       5
# 99  14.09         10.61       4
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=df.max()
p
# Out:
# cgpa            13.40
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
q=df.min()
q
# Out:
# cgpa            9.27
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
r=df.mean()
r
# Out:
# cgpa            10.9422
# resume_score     6.9305
# placed           0.5000
# dtype: float64

# %%
s=df.median()
s
# Out:
# cgpa            10.620
# resume_score     7.055
# placed           0.500
# dtype: float64

# %%
s=df.sum()
s
# Out:
# cgpa            1094.22
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
g=df.filter(items=['cgpa','placed'])
g

#df[['cgpa','placed']]
# Out:
#      cgpa  placed
# 0   12.14       1
# 1   10.17       0
# 2   12.27       1
# 3   10.88       1
# 4   11.52       1
# ..    ...     ...
# 95  10.33       0
# 96  12.23       1
# 97  10.65       0
# 98  12.14       1
# 99  10.09       0
#
# [100 rows x 2 columns]

# %%
s=df.filter(items=[5,6] ,axis=0) #axis=0 ==> row axis=1 ==> column
s
# Out:
#     cgpa  resume_score  placed
# 5  12.77          6.19       1
# 6   9.34          7.09       0

# %%
s=df.filter(like='5' ,axis=0)
s
# Out:
#      cgpa  resume_score  placed
# 5   12.77          6.19       1
# 15  12.88          5.93       1
# 25  11.76          5.68       1
# 35  12.07          7.48       1
# 45  12.10          5.44       1
# 50  12.22          6.74       1
# 51  10.54          7.39       0
# 52   9.90          7.50       0
# 53  10.00          7.16       0
# 54   9.92          7.18       0
# 55  10.94          6.87       1
# 56  10.13          6.43       0
# 57  10.34          7.21       0
# 58  10.47          7.37       0
# 59   9.95          7.57       0
# 65  10.04          8.75       0
# 75  10.34          7.94       1
# 85  10.72          5.46       0
# 95  10.33          6.38       0

# %%
s=df.to_dict() #save in dict

# %%
q=df.to_string() #save in string

# %%
idx =df.columns

# %%
label=df.columns[0] #first column label
label
# Out:
# 'cgpa'

# %%
p=df.columns.tolist # list of column label
p
# Out:
# <bound method IndexOpsMixin.tolist of Index(['cgpa', 'resume_score', 'placed'], dtype='object')>

# %%
q=df.columns.values # list of value of column 
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p=df.rename(columns={'cgpa':'half_yr_mrk','resume_score':'sem_mrk'}) #rename the colummn
p
# Out:
#     half_yr_mrk  sem_mrk  placed
# 0         12.14     6.52       1
# 1         10.17     5.17       0
# 2         12.27     8.86       1
# 3         10.88     7.27       1
# 4         11.52     7.30       1
# ..          ...      ...     ...
# 95        10.33     6.38       0
# 96        12.23     7.76       1
# 97        10.65     7.78       0
# 98        12.14     5.63       1
# 99        10.09     6.61       0
#
# [100 rows x 3 columns]

# %%
df['half']=df['cgpa'].where(df['cgpa']>50,other =0)
df.head(15)
# Out:
#      cgpa  resume_score  placed  half
# 0   12.14          6.52       1   0.0
# 1   10.17          5.17       0   0.0
# 2   12.27          8.86       1   0.0
# 3   10.88          7.27       1   0.0
# 4   11.52          7.30       1   0.0
# 5   12.77          6.19       1   0.0
# 6    9.34          7.09       0   0.0
# 7   10.56          6.29       0   0.0
# 8   10.32          6.71       0   0.0
# 9   11.69          7.12       1   0.0
# 10  10.18          6.35       0   0.0
# 11   9.44          6.54       0   0.0
# 12  10.09          7.01       0   0.0
# 13  12.50          5.09       1   0.0
# 14  11.51          6.25       1   0.0
